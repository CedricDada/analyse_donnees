# %%
import acp_functions
import numpy as np

# %%
X=acp_functions.content_csv("iris.csv")["data"][:, :-1]
Y=np.vectorize(acp_functions.convertir_en_reel)(X)
T=acp_functions.reduce(Y,acp_functions.usual_weight(Y))
acp_functions.completed_pca(T,acp_functions.usual_metrix(T),acp_functions.usual_weight(T),"iris.csv")
acp_functions.completed_pca(np.transpose(T),acp_functions.usual_weight(T),acp_functions.usual_metrix(T),"iris.csv")
